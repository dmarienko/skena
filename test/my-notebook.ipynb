# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Test 1

# %%
x = np.linspace(0.1,50,200)
plt.plot(np.exp(np.sin(x**2)) / np.sqrt(x) );

# %% [markdown]
# ## Test 123
